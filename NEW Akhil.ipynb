# %%
# %pip install semantic-link-labs
# %pip install semantic-link-sempy
# Out:
# StatementMeta(, 56c09688-a11b-4c7d-ae40-74848da01bb0, 8, Finished, Available, Finished)
# Collecting semantic-link-labs
#   Downloading semantic_link_labs-0.9.10-py3-none-any.whl (699 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.3/699.3 kB 22.8 MB/s eta 0:00:00
# Collecting semantic-link-sempy>=0.10.2 (from semantic-link-labs)
#   Downloading semantic_link_sempy-0.10.2-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 105.4 MB/s eta 0:00:00
# Collecting anytree (from semantic-link-labs)
#   Downloading anytree-2.13.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: powerbiclient in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-labs) (3.1.1)
# Collecting polib (from semantic-link-labs)
#   Downloading polib-1.2.0-py2.py3-none-any.whl (20 kB)
# Collecting jsonpath_ng (from semantic-link-labs)
#   Downloading jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Requirement already satisfied: clr-loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (0.2.6)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (0.20.1)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (12.0.1)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (1.3.0)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (4.66.1)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (13.6.0)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (2023.8.8)
# Requirement already satisfied: pandas>=1.5.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (2.0.3)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (3.4.1.5.3.20230713)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (2.31.0)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (3.8.6)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (8.14.0)
# Requirement already satisfied: ply in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jsonpath_ng->semantic-link-labs) (3.11)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (8.0.7)
# Requirement already satisfied: jupyter-ui-poll>=0.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (0.2.2)
# Requirement already satisfied: msal>=1.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (1.24.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.10.2->semantic-link-labs) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.10.2->semantic-link-labs) (3.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.10.2->semantic-link-labs) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.10.2->semantic-link-labs) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.3.1)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from clr-loader>=0.2.5->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.16.0)
# Requirement already satisfied: backcall in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.2.0)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.1.6)
# Requirement already satisfied: pickleshare in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (2.16.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (5.12.0)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (4.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (6.26.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.9)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (2.8.0)
# Requirement already satisfied: cryptography<44,>=0.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (41.0.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.10.2->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.10.2->semantic-link-labs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.10.2->semantic-link-labs) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.24.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pyspark>=3.4.1->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.26.17)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.10.2->semantic-link-labs) (3.0.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.10.2->semantic-link-labs) (3.2.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from cffi>=1.13->clr-loader>=0.2.5->semantic-link-sempy>=0.10.2->semantic-link-labs) (2.21)
# Requirement already satisfied: comm>=0.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (8.5.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.4.0)
# Requirement already satisfied: nest-asyncio in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (1.5.8)
# Requirement already satisfied: packaging in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (23.2)
# Requirement already satisfied: psutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (6.3.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.2.8)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (2.4.0)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.2.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.5.1)
# Installing collected packages: polib, jsonpath_ng, anytree, semantic-link-sempy, semantic-link-labs
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.9.0
#     Not uninstalling semantic-link-sempy at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-fa976557-45eb-40cf-88f8-4875ae6e76a7
#     Can't uninstall 'semantic-link-sempy'. No files were found to uninstall.
# Successfully installed anytree-2.13.0 jsonpath_ng-1.7.0 polib-1.2.0 semantic-link-labs-0.9.10 semantic-link-sempy-0.10.2
#
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: semantic-link-sempy in /nfs4/pyenv-fa976557-45eb-40cf-88f8-4875ae6e76a7/lib/python3.10/site-packages (0.10.2)
# Requirement already satisfied: clr-loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (0.2.6)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (0.20.1)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (12.0.1)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (1.3.0)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (4.66.1)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (13.6.0)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (2023.8.8)
# Requirement already satisfied: pandas>=1.5.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (2.0.3)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (3.4.1.5.3.20230713)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (2.31.0)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (3.8.6)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy) (8.14.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy) (3.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp>=3.8.6->semantic-link-sempy) (1.3.1)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from clr-loader>=0.2.5->semantic-link-sempy) (1.16.0)
# Requirement already satisfied: backcall in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy) (0.2.0)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy) (0.1.6)
# Requirement already satisfied: pickleshare in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy) (2.16.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy) (5.12.0)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from IPython>=8.14.0->semantic-link-sempy) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.5.3->semantic-link-sempy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.5.3->semantic-link-sempy) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.5.3->semantic-link-sempy) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.5.3->semantic-link-sempy) (1.24.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pyspark>=3.4.1->semantic-link-sempy) (0.10.9.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.31.0->semantic-link-sempy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.31.0->semantic-link-sempy) (1.26.17)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.31.0->semantic-link-sempy) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from rich>=13.3.5->semantic-link-sempy) (3.0.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy) (3.2.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from cffi>=1.13->clr-loader>=0.2.5->semantic-link-sempy) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.3.5->semantic-link-sempy) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython>=8.14.0->semantic-link-sempy) (0.2.8)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->semantic-link-sempy) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy) (2.4.0)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy) (0.2.2)
#
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %%
@log
def create_model_bpa_semantic_model(
    dataset: Optional[str] = icons.model_bpa_name,
    lakehouse: Optional[str | UUID] = None,
    lakehouse_workspace: Optional[str | UUID] = None,
):
    """
    Dynamically generates a Direct Lake semantic model based on the 'modelbparesults' delta table which contains the Best Practice Analyzer results.
    This semantic model used in combination with the corresponding Best Practice Analyzer report can be used to analyze multiple semantic models
    on multiple workspaces at once (and over time).

    The semantic model is always created within the same workspace as the lakehouse.

    Parameters
    ----------
    dataset : str, default='ModelBPA'
        Name of the semantic model to be created.
    lakehouse : str | uuid.UUID, default=None
        Name of the Fabric lakehouse which contains the 'modelbparesults' delta table.
        Defaults to None which resolves to the default lakehouse attached to the notebook.
    lakehouse_workspace : str | uuid.UUID, default=None
        The workspace in which the lakehouse resides.
        Defaults to None which resolves to the workspace of the attached lakehouse
        or if no lakehouse attached, resolves to the workspace of the notebook.
    """

    from sempy_labs.directlake import (
        generate_shared_expression,
        add_table_to_direct_lake_semantic_model,
    )
    from sempy_labs import create_blank_semantic_model, refresh_semantic_model
    from sempy_labs.tom import connect_semantic_model

    lakehouse_workspace_id = resolve_workspace_id(workspace=lakehouse_workspace)
    (lakehouse_id, lakehouse_name) = resolve_lakehouse_name_and_id(
        lakehouse=lakehouse, workspace=lakehouse_workspace_id
    )

    # Generate the shared expression based on the lakehouse and lakehouse workspace
    expr = generate_shared_expression(
        item_name=lakehouse_name,
        item_type="Lakehouse",
        workspace=lakehouse_workspace_id,
    )

    # Create blank model
    create_blank_semantic_model(
        dataset=dataset, workspace=lakehouse_workspace_id, overwrite=True
    )

    @retry(
        sleep_time=1,
        timeout_error_message=f"{icons.red_dot} Function timed out after 1 minute",
    )
    def dyn_connect():
        with connect_semantic_model(
            dataset=dataset, readonly=True, workspace=lakehouse_workspace_id
        ) as tom:

            tom.model

    dyn_connect()
    icons.sll_tags.append("ModelBPABulk")
    table_exists = False
    with connect_semantic_model(
        dataset=dataset, readonly=False, workspace=lakehouse_workspace_id
    ) as tom:
        t_name = "BPAResults"
        t_name_full = f"'{t_name}'"
        # Create the shared expression
        if not any(e.Name == "DatabaseQuery" for e in tom.model.Expressions):
            tom.add_expression(name="DatabaseQuery", expression=expr)
        # Add the table to the model
        if any(t.Name == t_name for t in tom.model.Tables):
            table_exists = True
    if not table_exists:
        add_table_to_direct_lake_semantic_model(
            dataset=dataset,
            table_name=t_name,
            lakehouse_table_name="modelbparesults",
            workspace=lakehouse_workspace_id,
            refresh=False,
        )
    with connect_semantic_model(
        dataset=dataset, readonly=False, workspace=lakehouse_workspace_id
    ) as tom:
        # Fix column names
        for c in tom.all_columns():
            if c.Name == "Dataset_Name":
                c.Name = "Model"
            elif c.Name == "Dataset_Id":
                c.Name = "Model Id"
            elif c.Name == "Workspace_Name":
                c.Name = "Workspace"
            elif c.Name == "Capacity_Name":
                c.Name = "Capacity"
            elif c.Name == "Configured_By":
                c.Name = "Model Owner"
            elif c.Name == "URL":
                c.DataCategory = "WebURL"
            elif c.Name == "RunId":
                tom.set_summarize_by(
                    table_name=c.Parent.Name, column_name=c.Name, value="None"
                )
            c.Name = c.Name.replace("_", " ")

        # Implement pattern for base measures
        def get_expr(table_name, calculation):
            return f"IF(HASONEFILTER({table_name}[RunId]),{calculation},CALCULATE({calculation},FILTER(VALUES({table_name}[RunId]),{table_name}[RunId] = [Max Run Id])))"

        # Add measures
        int_format = "#,0"
        m_name = "Max Run Id"
        if not any(m.Name == m_name for m in tom.all_measures()):
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=f"CALCULATE(MAX({t_name_full}[RunId]),{t_name_full}[RunId])",
                format_string=int_format,
            )
        m_name = "Capacities"
        if not any(m.Name == m_name for m in tom.all_measures()):
            calc = f"COUNTROWS(DISTINCT({t_name_full}[Capacity]))"
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=get_expr(t_name_full, calc),
                format_string=int_format,
            )
        m_name = "Models"
        if not any(m.Name == m_name for m in tom.all_measures()):
            calc = f"COUNTROWS(DISTINCT({t_name_full}[Model]))"
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=get_expr(t_name_full, calc),
                format_string=int_format,
            )
        m_name = "Workspaces"
        if not any(m.Name == m_name for m in tom.all_measures()):
            calc = f"COUNTROWS(DISTINCT({t_name_full}[Workspace]))"
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=get_expr(t_name_full, calc),
                format_string=int_format,
            )
        m_name = "Violations"
        if not any(m.Name == m_name for m in tom.all_measures()):
            calc = f"COUNTROWS({t_name_full})"
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=get_expr(t_name_full, calc),
                format_string=int_format,
            )
        m_name = "Error Violations"
        if not any(m.Name == m_name for m in tom.all_measures()):
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=f'CALCULATE([Violations],{t_name_full}[Severity]="Error")',
                format_string=int_format,
            )
        m_name = "Rules Violated"
        if not any(m.Name == m_name for m in tom.all_measures()):
            calc = f"COUNTROWS(DISTINCT({t_name_full}[Rule Name]))"
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=get_expr(t_name_full, calc),
                format_string=int_format,
            )
        m_name = "Rule Severity"
        if not any(m.Name == m_name for m in tom.all_measures()):
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=f"IF(ISFILTERED({t_name_full}[Rule Name]),IF( HASONEVALUE({t_name_full}[Rule Name]),MIN({t_name_full}[Severity])))",
            )
        # tom.add_measure(table_name=t_name, measure_name='Rules Followed', expression="[Rules] - [Rules Violated]")

    # Refresh the model
    refresh_semantic_model(dataset=dataset, workspace=lakehouse_workspace_id)
# Out:
# StatementMeta(, 56c09688-a11b-4c7d-ae40-74848da01bb0, 10, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 @log
#       2 def create_model_bpa_semantic_model(
#       3     dataset: Optional[str] = icons.model_bpa_name,
#       4     lakehouse: Optional[str | UUID] = None,
#       5     lakehouse_workspace: Optional[str | UUID] = None,
#       6 ):
#       7     """
#       8     Dynamically generates a Direct Lake semantic model based on the 'modelbparesults' delta table which contains the Best Practice Analyzer results.
#       9     This semantic model used in combination with the corresponding Best Practice Analyzer report can be used to analyze multiple semantic models
#    (...)
#      24         or if no lakehouse attached, resolves to the workspace of the notebook.
#      25     """
#      27     from sempy_labs.directlake import (
#      28         generate_shared_expression,
#      29         add_table_to_direct_lake_semantic_model,
#      30     )
#
# NameError: name 'log' is not defined

# %%
import sempy.fabric as fabric
import sempy_labs as labs
# Out:
# StatementMeta(, 15ccecaa-3527-4fdc-a008-58abcc49fbd0, 13, Finished, Available, Finished)

# %%
with connect_semantic_model(dataset=dataset, readonly=True, workspace=workspace) as tom:
    database = tom.model.Database
    print(database)
# Out:
# StatementMeta(, 15ccecaa-3527-4fdc-a008-58abcc49fbd0, 30, Finished, Available, Finished)
# fse_golden-30min

# %%
dir(database)
# Out:
# StatementMeta(, 15ccecaa-3527-4fdc-a008-58abcc49fbd0, -1, Cancelled, , Cancelled)

# %%
#Annotations
with connect_semantic_model(dataset=dataset, readonly=True, workspace=workspace) as tom:
    for annotation in tom.model.get_Database:
        print(f"Annotation Name: {annotation.Name}")
        print(f"Annotation Value: {annotation.Value}")
        print("-" * 40)

# %%
#Annotations
with connect_semantic_model(dataset=dataset, readonly=True, workspace=workspace) as tom:
    for annotation in tom.model.Annotations:
        print(f"Annotation Name: {annotation.Name}")
        print(f"Annotation Value: {annotation.Value}")
        print("-" * 40)
# Out:
# StatementMeta(, 15ccecaa-3527-4fdc-a008-58abcc49fbd0, 29, Finished, Available, Finished)
# Annotation Name: __PBI_TimeIntelligenceEnabled
# Annotation Value: 0
# ----------------------------------------
# Annotation Name: PBIDesktopVersion
# Annotation Value: 2.137.1102.0 (24.10)
# ----------------------------------------
# Annotation Name: PBI_QueryOrder
# Annotation Value: ["DimAD","DimDate","DimDealer","DimPart","FactADRetail","FactAMDRetail","Retail","RangeStart","RangeEnd","FactDespatch","Billing, Dispatch & Booking","FactBooking","FactRetailMonthPlan","Last Refresh","DimBusinessModel","LocationMapping","ProductMapping","3W Dom Retails","ZMList","TMList","AMList","DealerList","StateList","SparkURL","FactRetailADMonthPlan","FactBilling","workspaceName","dataflowName","DataflowNamerole","FactFestiveRetailsHourly","Date&Inv_Hour","FactRtliQubeDayPlan","FactAMDFundingcc","FactEMOSPlanFlag","DimFlagtable","FactADFundingcc","FactFestiveHourlyCumulativeRetails0Hour","FactFestiveHourlyCumulativeRetails"]
# ----------------------------------------
# Annotation Name: __TEdtr
# Annotation Value: 1
# ----------------------------------------

# %%
with connect_semantic_model(dataset=dataset, readonly=True, workspace=workspace) as tom:
    print(tom.model.Annotations)
    # for t in tom.model.Annotations:
        # print(t.get_Model)
        # print(dir(t))
# Out:
# StatementMeta(, 15ccecaa-3527-4fdc-a008-58abcc49fbd0, 28, Finished, Available, Finished)
# Microsoft.AnalysisServices.Tabular.ModelAnnotationCollection

# %%
dir(tom.model)
# Out:
# StatementMeta(, 15ccecaa-3527-4fdc-a008-58abcc49fbd0, 24, Finished, Available, Finished)
# ['AnalyticsAIMetadata',
#  'Annotations',
#  'ApplyAutomaticAggregations',
#  'ApplyPerformanceRecommendations',
#  'ApplyRefreshPolicies',
#  'AutomaticAggregationOptions',
#  'BindingInfoCollection',
#  'Clone',
#  'Collation',
#  'CopyFrom',
#  'CopyTo',
#  'Culture',
#  'Cultures',
#  'DataAccessOptions',
#  'DataSourceDefaultMaxConnections',
#  'DataSourceVariablesOverrideBehavior',
#  'DataSources',
#  'Database',
#  'DefaultDataView',
#  'DefaultMeasure',
#  'DefaultMode',
#  'DefaultPowerBIDataSourceVersion',
#  'Description',
#  'DirectLakeBehavior',
#  'DisableAutoExists',
#  'DiscourageCompositeModels',
#  'DiscourageImplicitMeasures',
#  'DiscourageReportMeasures',
#  'Equals',
#  'ExcludedArtifacts',
#  'ExecuteXmla',
#  'Expressions',
#  'ExtendedProperties',
#  'Finalize',
#  'ForceUniqueNames',
#  'Functions',
#  'GetCompatibilityRequirementByMembers',
#  'GetHashCode',
#  'GetType',
#  'HasLocalChanges',
#  'IsRemoved',
#  'MAttributes',
#  'MaxParallelismPerQuery',
#  'MaxParallelismPerRefresh',
#  'MemberwiseClone',
#  'Model',
#  'ModifiedTime',
#  'Name',
#  'ObjectType',
#  'Overloads',
#  'Parent',
#  'Perspectives',
#  'QueryGroups',
#  'ReferenceEquals',
#  'Refresh',
#  'Relationships',
#  'Rename',
#  'RequestRefresh',
#  'RequestRename',
#  'Roles',
#  'SaveChanges',
#  'Server',
#  'SourceQueryCulture',
#  'StorageLocation',
#  'StructureModifiedTime',
#  'Sync',
#  'Tables',
#  'ToString',
#  'UndoLocalChanges',
#  'Validate',
#  'ValueFilterBehavior',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__overloads__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'get_AnalyticsAIMetadata',
#  'get_Annotations',
#  'get_AutomaticAggregationOptions',
#  'get_BindingInfoCollection',
#  'get_Collation',
#  'get_Culture',
#  'get_Cultures',
#  'get_DataAccessOptions',
#  'get_DataSourceDefaultMaxConnections',
#  'get_DataSourceVariablesOverrideBehavior',
#  'get_DataSources',
#  'get_Database',
#  'get_DefaultDataView',
#  'get_DefaultMeasure',
#  'get_DefaultMode',
#  'get_DefaultPowerBIDataSourceVersion',
#  'get_Description',
#  'get_DirectLakeBehavior',
#  'get_DisableAutoExists',
#  'get_DiscourageCompositeModels',
#  'get_DiscourageImplicitMeasures',
#  'get_DiscourageReportMeasures',
#  'get_ExcludedArtifacts',
#  'get_Expressions',
#  'get_ExtendedProperties',
#  'get_ForceUniqueNames',
#  'get_Functions',
#  'get_HasLocalChanges',
#  'get_IsRemoved',
#  'get_MAttributes',
#  'get_MaxParallelismPerQuery',
#  'get_MaxParallelismPerRefresh',
#  'get_Model',
#  'get_ModifiedTime',
#  'get_Name',
#  'get_ObjectType',
#  'get_Parent',
#  'get_Perspectives',
#  'get_QueryGroups',
#  'get_Relationships',
#  'get_Roles',
#  'get_Server',
#  'get_SourceQueryCulture',
#  'get_StorageLocation',
#  'get_StructureModifiedTime',
#  'get_Tables',
#  'get_ValueFilterBehavior',
#  'set_AutomaticAggregationOptions',
#  'set_Collation',
#  'set_Culture',
#  'set_DataAccessOptions',
#  'set_DataSourceDefaultMaxConnections',
#  'set_DataSourceVariablesOverrideBehavior',
#  'set_DefaultDataView',
#  'set_DefaultMeasure',
#  'set_DefaultMode',
#  'set_DefaultPowerBIDataSourceVersion',
#  'set_Description',
#  'set_DirectLakeBehavior',
#  'set_DisableAutoExists',
#  'set_DiscourageCompositeModels',
#  'set_DiscourageImplicitMeasures',
#  'set_DiscourageReportMeasures',
#  'set_ForceUniqueNames',
#  'set_MAttributes',
#  'set_MaxParallelismPerQuery',
#  'set_MaxParallelismPerRefresh',
#  'set_Name',
#  'set_SourceQueryCulture',
#  'set_StorageLocation',
#  'set_ValueFilterBehavior']

# %%
import sempy
sempy.fabric._client._utils._init_analysis_services()
import Microsoft.AnalysisServices.Tabular as TOM
import pandas as pd
# Out:
# StatementMeta(, 6154b121-9922-4d54-b73b-4d58a9cf43a0, 10, Finished, Available, Finished)

# %%
import sempy_labs as labs
from sempy_labs.tom import connect_semantic_model
# Out:
# StatementMeta(, 6154b121-9922-4d54-b73b-4d58a9cf43a0, 11, Finished, Available, Finished)

# %%
dataset = 'fse_golden-30min' # Enter dataset name
workspace = 'BI Governance'
# Out:
# StatementMeta(, 15ccecaa-3527-4fdc-a008-58abcc49fbd0, 19, Finished, Available, Finished)

# %%
with connect_semantic_model(dataset=dataset, readonly=False, workspace=workspace) as tom:
    tom.set_vertipaq_annotations()

    for t in tom.model.Tables:
        rc = tom.row_count(object = t)
        print(f"{t.Name}  : {str(rc)}")
        for c in t.Columns:
            col_size = tom.total_size(object=c)
            print(labs.format_dax_object_name(t.Name, c.Name) + ' : ' + str(col_size))
# Out:
# StatementMeta(, 15ccecaa-3527-4fdc-a008-58abcc49fbd0, 23, Finished, Available, Finished)
# DimAD  : 8381
# 'DimAD'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'DimAD'[AD ID] : 248852
# 'DimAD'[AMD ID] : 62108
# 'DimAD'[AD Name] : 308463
# 'DimAD'[AD] : 464795
# 'DimAD'[City] : 361124
# DimDate  : 2922
# 'DimDate'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'DimDate'[Datekey] : 135076
# 'DimDate'[Year] : 1664
# 'DimDate'[Month] : 23112
# 'DimDate'[Start Of Month] : 6628
# 'DimDate'[End Of Month] : 6640
# 'DimDate'[Date] : 135076
# 'DimDate'[StartDay] : 1520
# 'DimDate'[EndDay] : 1520
# 'DimDate'[FY] : 17704
# 'DimDate'[Month Number] : 3088
# 'DimDate'[Day] : 3724
# 'DimDate'[CurrentMonth] : 1528
# 'DimDate'[key] : 19768
# DimDealer  : 7558
# 'DimDealer'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'DimDealer'[Active] : 17616
# 'DimDealer'[Pin Code] : 99468
# 'DimDealer'[City] : 76772
# 'DimDealer'[Territory] : 28964
# 'DimDealer'[Area] : 21424
# 'DimDealer'[State] : 20580
# 'DimDealer'[Zone] : 19698
# 'DimDealer'[Country ID] : 1536
# 'DimDealer'[Country] : 17386
# 'DimDealer'[Dealer] : 476005
# 'DimDealer'[Dealer ID] : 238096
# 'DimDealer'[Dealer Name] : 366937
# 'DimDealer'[TerritoryID] : 30972
# 'DimDealer'[DT Flag] : 17382
# 'DimDealer'[Apache Flag] : 17318
# 'DimDealer'[EMS Flag] : 17326
# 'DimDealer'[DealerTown] : 55706
# 'DimDealer'[IndustryTown] : 42900
# 'DimDealer'[PremiumDealer] : 17374
# 'DimDealer'[is_b2c] : 1784
# 'DimDealer'[Chronic AMD] : 17342
# DimPart  : 7970
# 'DimPart'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'DimPart'[Part ID] : 321687
# 'DimPart'[Model ID] : 38269
# 'DimPart'[Model] : 19224
# 'DimPart'[Part Desc] : 477651
# 'DimPart'[Model Desc] : 51789
# 'DimPart'[Short Code] : 17986
# 'DimPart'[Industry] : 17316
# 'DimPart'[Status] : 17362
# 'DimPart'[SERIES_DESC] : 19426
# 'DimPart'[ExclusionFlag] : 1520
# 'DimPart'[Category] : 17484
# 'DimPart'[Segment] : 17522
# 'DimPart'[Sub Segment] : 17616
# 'DimPart'[New Variants] : 17410
# FactADRetail  : 293811
# 'FactADRetail'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactADRetail'[ad_id] : 607393
# 'FactADRetail'[dealer_id] : 208900
# 'FactADRetail'[part_id] : 246590
# 'FactADRetail'[inv_dt] : 71904
# 'FactADRetail'[total_counter] : 2064
# 'FactADRetail'[net_amd_ad] : 1992
# 'FactADRetail'[Business_Model] : 17304
# FactAMDRetail  : 357365
# 'FactAMDRetail'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactAMDRetail'[dealer_id] : 622378
# 'FactAMDRetail'[part_id] : 322342
# 'FactAMDRetail'[inv_dt] : 105920
# 'FactAMDRetail'[net_counter] : 4724
# 'FactAMDRetail'[net_asc] : 4332
# 'FactAMDRetail'[net_mbo] : 5016
# 'FactAMDRetail'[other_vendor_grn] : 2184
# 'FactAMDRetail'[total_csd] : 2344
# 'FactAMDRetail'[return_qty] : 2584
# 'FactAMDRetail'[net_retail] : 8096
# 'FactAMDRetail'[Business_Model] : 17352
# Retail  : 0
# 'Retail'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'Retail'[Column1] : 720
# FactDespatch  : 66779
# 'FactDespatch'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactDespatch'[Dealer_ID] : 154228
# 'FactDespatch'[PLANT] : 20344
# 'FactDespatch'[BUSINESS_MODEL] : 17648
# 'FactDespatch'[Part_ID] : 87842
# 'FactDespatch'[SHPT_DATE] : 45868
# 'FactDespatch'[Despatch] : 10048
# FactBilling  : 65706
# 'FactBilling'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactBilling'[BILLING_DATE] : 17044
# 'FactBilling'[BUSINESS_MODEL] : 17536
# 'FactBilling'[Dealer_ID] : 152568
# 'FactBilling'[Part_ID] : 101902
# 'FactBilling'[Billing_Qty] : 9088
# Billing, Dispatch & Booking  : 0
# 'Billing, Dispatch & Booking'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'Billing, Dispatch & Booking'[Column1] : 720
# FactBooking  : 13450
# 'FactBooking'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactBooking'[DEALER_ID] : 79644
# 'FactBooking'[BOOKING_DATE] : 4824
# 'FactBooking'[PART_ID] : 48568
# 'FactBooking'[CUST_TY_ID] : 1696
# 'FactBooking'[STATUS] : 17290
# 'FactBooking'[QUANTITY] : 1704
# FactRetailMonthPlan  : 0
# 'FactRetailMonthPlan'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactRetailMonthPlan'[dealer_id] : 720
# 'FactRetailMonthPlan'[model_id] : 720
# 'FactRetailMonthPlan'[Plan_date] : 432
# 'FactRetailMonthPlan'[day_plan] : 432
# 'FactRetailMonthPlan'[Business_Model] : 720
# 'FactRetailMonthPlan'[Flag] : 720
# Last Refresh  : 1
# 'Last Refresh'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'Last Refresh'[Last Refresh] : 296
# DimBusinessModel  : 4
# 'DimBusinessModel'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'DimBusinessModel'[BusinessModel] : 17392
# 'DimBusinessModel'[SortOrder] : 304
# LocationMapping  : 90
# 'LocationMapping'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'LocationMapping'[Location] : 18280
# 'LocationMapping'[Area] : 18036
# 'LocationMapping'[LocationSortOrder] : 512
# ProductMapping  : 55
# 'ProductMapping'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'ProductMapping'[Product] : 18000
# 'ProductMapping'[Model] : 17790
# 'ProductMapping'[ProductSortOrder] : 408
# 'ProductMapping'[ShortCode] : 17844
# ZMList  : 60
# 'ZMList'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'ZMList'[email] : 19960
# 'ZMList'[Location] : 17520
# TMList  : 191
# 'TMList'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'TMList'[email] : 28678
# 'TMList'[Location] : 23338
# AMList  : 198
# 'AMList'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'AMList'[email] : 23878
# 'AMList'[Location] : 18116
# DealerList  : 2174
# 'DealerList'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'DealerList'[DealerID] : 62196
# 'DealerList'[email] : 116045
# StateList  : 33
# 'StateList'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'StateList'[email] : 18312
# 'StateList'[Location] : 17706
# FactRetailADMonthPlan  : 0
# 'FactRetailADMonthPlan'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactRetailADMonthPlan'[dealer_id] : 720
# 'FactRetailADMonthPlan'[model_id] : 720
# 'FactRetailADMonthPlan'[Plan_date] : 432
# 'FactRetailADMonthPlan'[RTLDAYPLAN] : 432
# 'FactRetailADMonthPlan'[Business_Model] : 720
# FactFestiveRetailsHourly  : 74691
# 'FactFestiveRetailsHourly'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactFestiveRetailsHourly'[inv_dt] : 26904
# 'FactFestiveRetailsHourly'[inv_hr] : 51208
# 'FactFestiveRetailsHourly'[model] : 52586
# 'FactFestiveRetailsHourly'[area_name] : 30502
# 'FactFestiveRetailsHourly'[zone_name] : 19300
# 'FactFestiveRetailsHourly'[type] : 23270
# 'FactFestiveRetailsHourly'[net_rtl] : 46752
# 'FactFestiveRetailsHourly'[hourKey] : 102486
# Date&Inv_Hour  : 384
# 'Date&Inv_Hour'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'Date&Inv_Hour'[Date] : 1888
# 'Date&Inv_Hour'[hourKey] : 34272
# 'Date&Inv_Hour'[Inv_hr] : 640
# 'Date&Inv_Hour'[hour] : 2080
# 'Date&Inv_Hour'[Date_hr] : 15496
# 'Date&Inv_Hour'[Hour Formatted] : 18184
# 'Date&Inv_Hour'[Report_time] : 15652
# FactRtliQubeDayPlan  : 356078
# 'FactRtliQubeDayPlan'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactRtliQubeDayPlan'[DateKey] : 175112
# 'FactRtliQubeDayPlan'[Model] : 17292
# 'FactRtliQubeDayPlan'[DayiQubeRtlPlan] : 7516
# 'FactRtliQubeDayPlan'[dealer_code] : 439996
# FactAMDFundingcc  : 2987
# 'FactAMDFundingcc'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactAMDFundingcc'[dealer_id] : 106604
# 'FactAMDFundingcc'[invfundact] : 24804
# 'FactAMDFundingcc'[ccact] : 25228
# 'FactAMDFundingcc'[Totalfundcc] : 48340
# FactEMOSPlanFlag  : 6162879
# 'FactEMOSPlanFlag'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 768
# 'FactEMOSPlanFlag'[DEALER_ID] : 813332
# 'FactEMOSPlanFlag'[WEEK_DATE] : 5379576
# 'FactEMOSPlanFlag'[P_TOTAL] : 7872
# 'FactEMOSPlanFlag'[EmosplanFlag] : 17998
# DimFlagtable  : 2
# 'DimFlagtable'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'DimFlagtable'[Flag] : 304
# 'DimFlagtable'[Flagname] : 17318
# FactADFundingcc  : 7185
# 'FactADFundingcc'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactADFundingcc'[dealer_id] : 232108
# 'FactADFundingcc'[invfundact] : 1480
# 'FactADFundingcc'[ccact] : 1504
# 'FactADFundingcc'[Totalfundcc] : 1536
# FactFestiveHourlyCumulativeRetails0Hour  : 2325
# 'FactFestiveHourlyCumulativeRetails0Hour'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactFestiveHourlyCumulativeRetails0Hour'[inv_dt] : 1536
# 'FactFestiveHourlyCumulativeRetails0Hour'[inv_hr] : 1520
# 'FactFestiveHourlyCumulativeRetails0Hour'[model] : 18870
# 'FactFestiveHourlyCumulativeRetails0Hour'[area_name] : 19494
# 'FactFestiveHourlyCumulativeRetails0Hour'[zone_name] : 17088
# 'FactFestiveHourlyCumulativeRetails0Hour'[type] : 17288
# 'FactFestiveHourlyCumulativeRetails0Hour'[net_rtl] : 10216
# 'FactFestiveHourlyCumulativeRetails0Hour'[hourKey] : 17544
# FactFestiveHourlyCumulativeRetails  : 77016
# 'FactFestiveHourlyCumulativeRetails'[RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61] : 128
# 'FactFestiveHourlyCumulativeRetails'[inv_dt] : 28688
# 'FactFestiveHourlyCumulativeRetails'[inv_hr] : 51128
# 'FactFestiveHourlyCumulativeRetails'[model] : 54682
# 'FactFestiveHourlyCumulativeRetails'[area_name] : 35326
# 'FactFestiveHourlyCumulativeRetails'[zone_name] : 19692
# 'FactFestiveHourlyCumulativeRetails'[type] : 23942
# 'FactFestiveHourlyCumulativeRetails'[net_rtl] : 94776
# 'FactFestiveHourlyCumulativeRetails'[hourKey] : 102426
# ---------------------------------------------------------------------------
# OperationException                        Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 with connect_semantic_model(dataset=dataset, readonly=False, workspace=workspace) as tom:
#       2     tom.set_vertipaq_annotations()
#       4     for t in tom.model.Tables:
#
# File ~/cluster-env/trident_env/lib/python3.10/contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     140 if typ is None:
#     141     try:
# --> 142         next(self.gen)
#     143     except StopIteration:
#     144         return False
#
# File /nfs4/pyenv-a6d5851e-1161-460d-a666-698887dea8b7/lib/python3.10/site-packages/sempy_labs/tom/_model.py:5193, in connect_semantic_model(dataset, readonly, workspace)
#    5191     yield tw
#    5192 finally:
# -> 5193     tw.close()
#
# File /nfs4/pyenv-a6d5851e-1161-460d-a666-698887dea8b7/lib/python3.10/site-packages/sempy_labs/tom/_model.py:5139, in TOMWrapper.close(self)
#    5136     except Exception:
#    5137         pass
# -> 5139 self.model.SaveChanges()
#    5141 if len(self._tables_added) > 0:
#    5142     refresh_semantic_model(
#    5143         dataset=self._dataset_id,
#    5144         tables=self._tables_added,
#    5145         workspace=self._workspace_id,
#    5146     )
#
# OperationException: Failed to save modifications to the server. Error returned: 'It looks like you can't make changes to this dataset. Please contact a capacity administrator to make sure XMLA read/write support is enabled in the capacity settings on the Power BI Premium capacity, and then try again. For additional information, see 'XMLA read/write support' in the product documentation.
#
# Technical Details:
# RootActivityId: 685da818-c780-4b5b-b69b-c8c918531b61
# Date (UTC): 4/28/2025 6:17:49 AM
# '.
#    at Microsoft.AnalysisServices.Tabular.Model.SaveChangesImpl(SaveFlags flags, Int32 maxParallelism)
#    at Microsoft.AnalysisServices.Tabular.Model.SaveChanges()

# %%
import Microsoft.AnalysisServices.Tabular as TOM
from sempy.fabric._client._utils import _init_analysis_services
from sempy.fabric import workspace  # This is correct!!

# Initialize TOM environment
_init_analysis_services()

# Get the workspace and dataset
ws = workspace.get_workspace("BI Governance")
ds = workspace.get_dataset(ws.id, "fse_golden-30min")
model = ds.model  # This is a TOM.Model

# Loop through tables and partitions
for table in model.tables:
    print(f"Table: {table.name}")
    for partition in table.partitions:
        source = partition.source
        if isinstance(source, TOM.MPartitionSource):
            print(f"  Partition: {partition.name}")
            print(f"  M Query:\n{source.Expression}")
        else:
            print(f"  Partition {partition.name} is not an MPartitionSource.")
# Out:
# StatementMeta(, 15ccecaa-3527-4fdc-a008-58abcc49fbd0, 22, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[43], line 3
#       1 import Microsoft.AnalysisServices.Tabular as TOM
#       2 from sempy.fabric._client._utils import _init_analysis_services
# ----> 3 from sempy.fabric import workspace  # This is correct!!
#       5 # Initialize TOM environment
#       6 _init_analysis_services()
#
# ImportError: cannot import name 'workspace' from 'sempy.fabric' (/nfs4/pyenv-a6d5851e-1161-460d-a666-698887dea8b7/lib/python3.10/site-packages/sempy/fabric/__init__.py)

# %%
with connect_semantic_model(dataset=dataset, readonly=True, workspace=workspace) as tom:
    for p in tom.all_partitions():
        print(p.Name)
# Out:
# StatementMeta(, 15ccecaa-3527-4fdc-a008-58abcc49fbd0, 20, Finished, Available, Finished)
# DimAD-c3141ce4-53eb-4f09-95d4-46520379515b
# DimDate-0a638352-c190-46c4-ab3c-736f66f3d34a
# DimDealer-77f2cd30-7c73-4b34-8347-e5e84371c9d4
# DimPart-c483ef97-3005-49a4-bd55-7da65e2097a1
# FactADRetail-453d5af1-aadf-46fe-b94f-969d3c22af8f
# FactAMDRetail-c51fe981-fde8-44b4-9f12-f26a499df35b
# Retail-a342db34-e5fa-4520-bf92-1e731dc118fe
# FactDespatch-1b6abf6a-8517-498f-9ab9-4b507c83d3c7
# FactBilling-1a664c23-9f3f-4d3a-8fca-edbaa31eeff7
# Billing, Dispatch & Booking-cf1b8dcb-d754-4c46-926b-cecc6b336f87
# FactBooking-cb11ce23-72c3-42c1-b46f-ae3e5ff833e6
# FactRetailMonthPlan-dc9324a2-a41f-4a71-8d75-11289d52e86f
# Last Refresh-c7d416f7-d9ba-45bf-a9f0-28686e08c46e
# DimBusinessModel-06c903f9-c5d8-46b4-ae3d-07be0efd7505
# LocationMapping-5aa482d6-ad8d-4532-8df3-48a9dd637173
# ProductMapping-f8fab31d-8e88-460d-8465-2f80527ad80f
# ZMList-a2a9aac9-42bb-4608-84bb-bdf0ff83d9f7
# TMList-c8660dfb-1357-475d-aff4-d00f93dec553
# AMList-7dbb0468-bf65-4543-9533-e012e74659fb
# DealerList-710fcf90-8d4c-4de9-86cf-a5a600211389
# StateList-e61bc0c0-510f-48a9-9505-7d69add1a94d
# FactRetailADMonthPlan-1b217599-6bb6-4807-bed2-e5b5bb87322e
# FactFestiveRetailsHourly-27be28b3-fa63-431a-b4dc-3f9bae1e6002
# Date&Inv_Hour-f2a43f75-d826-4f7f-bcd7-e27291e27feb
# FactRtliQubeDayPlan-7984d876-cf34-436f-a943-9a447ce2cf7b
# FactAMDFundingcc
# FactEMOSPlanFlag
# DimFlagtable
# FactADFundingcc
# FactFestiveHourlyCumulativeRetails0Hour
# FactFestiveHourlyCumulativeRetails

# %%
dir(TOM)
# Out:
# StatementMeta(, 15ccecaa-3527-4fdc-a008-58abcc49fbd0, 12, Finished, Available, Finished)
# ['AggregateFunction',
#  'Alignment',
#  'AlternateOf',
#  'AlternateOfAnnotationCollection',
#  'AnalyticsAIMetadata',
#  'AnalyticsAIMetadataCollection',
#  'Annotation',
#  'Assembly',
#  'AttributeHierarchy',
#  'AttributeHierarchyAnnotationCollection',
#  'AttributeHierarchyExtendedPropertyCollection',
#  'AuthenticationKind',
#  'AutomaticAggregationOptions',
#  'BasicRefreshPolicy',
#  'BindingInfo',
#  'BindingInfoAnnotationCollection',
#  'BindingInfoCollection',
#  'BindingInfoExtendedPropertyCollection',
#  'BindingInfoType',
#  'CalculatedColumn',
#  'CalculatedPartitionSource',
#  'CalculatedTableColumn',
#  'CalculationGroup',
#  'CalculationGroupAnnotationCollection',
#  'CalculationGroupExpression',
#  'CalculationGroupSelectionMode',
#  'CalculationGroupSource',
#  'CalculationItem',
#  'CalculationItemCollection',
#  'Calendar',
#  'CalendarCollection',
#  'ChangedProperty',
#  'ClrAssembly',
#  'Column',
#  'ColumnAnnotationCollection',
#  'ColumnChangedPropertyCollection',
#  'ColumnCollection',
#  'ColumnExtendedPropertyCollection',
#  'ColumnPermission',
#  'ColumnPermissionAnnotationCollection',
#  'ColumnPermissionCollection',
#  'ColumnPermissionExtendedPropertyCollection',
#  'ColumnType',
#  'ComAssembly',
#  'CompatibilityViolationException',
#  'ConnectionAddress',
#  'ConnectionAddressProperty',
#  'ConnectionDetails',
#  'ContentType',
#  'Credential',
#  'CredentialProperty',
#  'CrossFilteringBehavior',
#  'Culture',
#  'CultureAnnotationCollection',
#  'CultureCollection',
#  'CultureExtendedPropertyCollection',
#  'CustomJsonProperty',
#  'CustomJsonProperty`1',
#  'DataAccessOptions',
#  'DataBindingHint',
#  'DataColumn',
#  'DataCoverageDefinition',
#  'DataCoverageDefinitionAnnotationCollection',
#  'DataSource',
#  'DataSourceAnnotationCollection',
#  'DataSourceCollection',
#  'DataSourceExtendedPropertyCollection',
#  'DataSourceOptions',
#  'DataSourceProtocol',
#  'DataSourceType',
#  'DataSourceVariablesOverrideBehaviorType',
#  'DataType',
#  'DataViewType',
#  'Database',
#  'DatabaseCollection',
#  'DatasourceIsolation',
#  'DateTimeRelationshipBehavior',
#  'DeserializeOptions',
#  'DetailRowsDefinition',
#  'DirectLakeBehavior',
#  'EncodingHintType',
#  'EntityPartitionSource',
#  'EvaluationBehavior',
#  'ExcludedArtifact',
#  'ExpressionKind',
#  'ExtendedProperty',
#  'ExtendedPropertyType',
#  'ExternalModelRoleMember',
#  'FormatStringDefinition',
#  'Function',
#  'FunctionAnnotationCollection',
#  'FunctionChangedPropertyCollection',
#  'FunctionCollection',
#  'FunctionExtendedPropertyCollection',
#  'GroupByColumn',
#  'GroupByColumnCollection',
#  'Hierarchy',
#  'HierarchyAnnotationCollection',
#  'HierarchyChangedPropertyCollection',
#  'HierarchyCollection',
#  'HierarchyExcludedArtifactCollection',
#  'HierarchyExtendedPropertyCollection',
#  'HierarchyHideMembersType',
#  'IMajorObject',
#  'IMetadataObjectWithLineage',
#  'ITrace',
#  'ImpersonationMode',
#  'InferredPartitionSource',
#  'JsonExtendedProperty',
#  'JsonScripter',
#  'JsonSerializer',
#  'KPI',
#  'KPIAnnotationCollection',
#  'KPIExtendedPropertyCollection',
#  'Level',
#  'LevelAnnotationCollection',
#  'LevelChangedPropertyCollection',
#  'LevelCollection',
#  'LevelExtendedPropertyCollection',
#  'LinguisticMetadata',
#  'LinguisticMetadataAnnotationCollection',
#  'LinguisticMetadataExtendedPropertyCollection',
#  'MPartitionSource',
#  'Measure',
#  'MeasureAnnotationCollection',
#  'MeasureChangedPropertyCollection',
#  'MeasureCollection',
#  'MeasureExtendedPropertyCollection',
#  'MetadataObject',
#  'MetadataObjectCollection',
#  'MetadataObjectCollection`2',
#  'MetadataPermission',
#  'ModeType',
#  'Model',
#  'ModelAnnotationCollection',
#  'ModelExcludedArtifactCollection',
#  'ModelExtendedPropertyCollection',
#  'ModelOperationResult',
#  'ModelPermission',
#  'ModelRole',
#  'ModelRoleAnnotationCollection',
#  'ModelRoleCollection',
#  'ModelRoleExtendedPropertyCollection',
#  'ModelRoleMember',
#  'ModelRoleMemberAnnotationCollection',
#  'ModelRoleMemberCollection',
#  'ModelRoleMemberExtendedPropertyCollection',
#  'NamedExpression',
#  'NamedExpressionAnnotationCollection',
#  'NamedExpressionCollection',
#  'NamedExpressionExcludedArtifactCollection',
#  'NamedExpressionExtendedPropertyCollection',
#  'NamedMetadataObject',
#  'NamedMetadataObjectCollection',
#  'NamedMetadataObjectCollection`2',
#  'ObjectImpact',
#  'ObjectReference',
#  'ObjectState',
#  'ObjectTranslation',
#  'ObjectTranslationCollection',
#  'ObjectType',
#  'OutOfSyncException',
#  'ParquetPartitionSource',
#  'Partition',
#  'PartitionAnnotationCollection',
#  'PartitionCollection',
#  'PartitionExtendedPropertyCollection',
#  'PartitionSource',
#  'PartitionSourceType',
#  'Perspective',
#  'PerspectiveAnnotationCollection',
#  'PerspectiveCollection',
#  'PerspectiveColumn',
#  'PerspectiveColumnAnnotationCollection',
#  'PerspectiveColumnCollection',
#  'PerspectiveColumnExtendedPropertyCollection',
#  'PerspectiveExtendedPropertyCollection',
#  'PerspectiveHierarchy',
#  'PerspectiveHierarchyAnnotationCollection',
#  'PerspectiveHierarchyCollection',
#  'PerspectiveHierarchyExtendedPropertyCollection',
#  'PerspectiveMeasure',
#  'PerspectiveMeasureAnnotationCollection',
#  'PerspectiveMeasureCollection',
#  'PerspectiveMeasureExtendedPropertyCollection',
#  'PerspectiveSet',
#  'PerspectiveSetAnnotationCollection',
#  'PerspectiveSetCollection',
#  'PerspectiveSetExtendedPropertyCollection',
#  'PerspectiveTable',
#  'PerspectiveTableAnnotationCollection',
#  'PerspectiveTableCollection',
#  'PerspectiveTableExtendedPropertyCollection',
#  'PolicyRangePartitionSource',
#  'PowerBIDataSourceVersion',
#  'PrivacyClass',
#  'PropertyChangeEntry',
#  'ProviderDataSource',
#  'QueryGroup',
#  'QueryGroupAnnotationCollection',
#  'QueryGroupCollection',
#  'QueryPartitionSource',
#  'RefreshGranularityType',
#  'RefreshPolicy',
#  'RefreshPolicyAnnotationCollection',
#  'RefreshPolicyBehavior',
#  'RefreshPolicyExtendedPropertyCollection',
#  'RefreshPolicyMode',
#  'RefreshPolicyType',
#  'RefreshType',
#  'RelatedColumnDetails',
#  'Relationship',
#  'RelationshipAnnotationCollection',
#  'RelationshipChangedPropertyCollection',
#  'RelationshipCollection',
#  'RelationshipEndCardinality',
#  'RelationshipExtendedPropertyCollection',
#  'RelationshipType',
#  'RemovedSubtreeEntry',
#  'Role',
#  'RoleCollection',
#  'RoleMemberType',
#  'RowNumberColumn',
#  'SaveFlags',
#  'SaveOptions',
#  'SecurityFilteringBehavior',
#  'SerializeOptions',
#  'Server',
#  'SessionTrace',
#  'Set',
#  'SetAnnotationCollection',
#  'SetCollection',
#  'SetExtendedPropertyCollection',
#  'SingleColumnRelationship',
#  'StringExtendedProperty',
#  'StructuredDataSource',
#  'SummarizationType',
#  'SyncOptions',
#  'Table',
#  'TableAnnotationCollection',
#  'TableChangedPropertyCollection',
#  'TableCollection',
#  'TableExcludedArtifactCollection',
#  'TableExtendedPropertyCollection',
#  'TablePermission',
#  'TablePermissionAnnotationCollection',
#  'TablePermissionCollection',
#  'TablePermissionExtendedPropertyCollection',
#  'TimeUnit',
#  'TimeUnitColumnAssociation',
#  'TimeUnitColumnAssociationCollection',
#  'TmdlSerializer',
#  'TomException',
#  'TomInternalException',
#  'TomValidationException',
#  'Trace',
#  'TraceCollection',
#  'TraceColumnCollection',
#  'TraceEvent',
#  'TraceEventArgs',
#  'TraceEventCollection',
#  'TraceEventHandler',
#  'TraceStoppedEventArgs',
#  'TraceStoppedEventHandler',
#  'TranslatedProperty',
#  'Utils',
#  'ValidationError',
#  'ValidationResult',
#  'ValueFilterBehaviorType',
#  'Variation',
#  'VariationAnnotationCollection',
#  'VariationCollection',
#  'VariationExtendedPropertyCollection',
#  'WindowsModelRoleMember',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__file__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__loader__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__package__',
#  '__path__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__spec__',
#  '__str__',
#  '__subclasshook__']

# %%
res = labs.list_data_pipelines()
# Out:
# StatementMeta(, 98e0d5f5-6659-4821-8803-46c64c3d036d, 13, Finished, Available, Finished)

# %%
res
# Out:
# StatementMeta(, 98e0d5f5-6659-4821-8803-46c64c3d036d, 14, Finished, Available, Finished)
#                               Data Pipeline Name  \
# 0                                      pipeline1
# 1                                      Load Data
# 2                                     pl_LoadDim
# 3                                       learning
# 4                                 Load_Items_E2E
# 5                            Load_Activities_E2E
# 6                            Load_Capacities_E2E
# 7                 Load_Capacity_Refreshables_E2E
# 8                        Load_PBI_Workspaces_E2E
# 9                             Load_Inventory_E2E
# 10                      Load_Tenant_Settings_E2E
# 11  Load_Delegated_Tenant_Settings_Overrides_E2E
# 12                      Load_Git_Connections_E2E
# 13                          Maintenance_for_FUAM
# 14                     Load_Capacity_Metrics_E2E
# 15                            Load_FUAM_Data_E2E
#
#                         Data Pipeline ID        Description
# 0   f30c12b3-b45d-44f0-a9ec-88acaa9811aa
# 1   d1e21f10-5157-4087-9bf1-af2ae88335ae
# 2   b042114e-728e-407b-add9-76b36b107b10
# 3   e060e855-4d34-4c61-9e9c-dfaa762efeb1
# 4   0a09bc7d-6c20-424c-ac19-c3af22575d9e  Imported from fab
# 5   48fa2238-b5a3-4384-9a76-9cc81e4b9f96  Imported from fab
# 6   ed81ab77-f551-47e7-a021-126fb1791480  Imported from fab
# 7   74a2ab42-aebc-44cd-800f-c8cc32bed861  Imported from fab
# 8   4bca9ec0-397d-42fc-bfd3-94b27d9709aa  Imported from fab
# 9   c141ffaa-50bc-441f-8724-24eaf83df6c6  Imported from fab
# 10  04fe1914-f729-4c5e-9deb-97c277518190  Imported from fab
# 11  11ca84de-be57-4b63-8e6d-64282cac6681  Imported from fab
# 12  0c9910cb-9d30-4e17-983f-14d230ff55a3  Imported from fab
# 13  01a1abf7-d811-4d45-a7e2-6f06968a5844  Imported from fab
# 14  563f6a48-84a4-442c-b291-5313725ae95d  Imported from fab
# 15  643595af-e3c6-4464-a3ee-5f3f336a2c09  Imported from fab

# %%
help(labs.list_data_pipelines)
# Out:
# StatementMeta(, 5b0f876c-3857-479a-9aef-b2194ad3d831, 28, Finished, Available, Finished)
# Help on function list_data_pipelines in module sempy_labs._data_pipelines:
#
# list_data_pipelines(workspace: Union[str, uuid.UUID, NoneType] = None) -> pandas.core.frame.DataFrame
#     Shows the data pipelines within a workspace.
#
#     This is a wrapper function for the following API: `Items - List Data Pipelines <https://learn.microsoft.com/rest/api/fabric/datapipeline/items/list-data-pipelines>`_.
#
#     Parameters
#     ----------
#     workspace : str | uuid.UUID, default=None
#         The Fabric workspace name or ID.
#         Defaults to None which resolves to the workspace of the attached lakehouse
#         or if no lakehouse attached, resolves to the workspace of the notebook.
#
#     Returns
#     -------
#     pandas.DataFrame
#         A pandas dataframe showing the data pipelines within a workspace.

# %%
import sempy_labs as labs
# Out:
# StatementMeta(, f5d04f59-1528-41b5-9775-3704c80d31e9, 53, Finished, Available, Finished)

# %%
res = labs.list_dataflows(workspace="SST D&AI")
# Out:
# StatementMeta(, f5d04f59-1528-41b5-9775-3704c80d31e9, 58, Finished, Available, Finished)

# %%
display(res)
# Out:
# StatementMeta(, f5d04f59-1528-41b5-9775-3704c80d31e9, 59, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 691c3dd4-63a8-4511-a6f4-2fb17b10162d)

# %%
help(labs.list_dataflows)
# Out:
# StatementMeta(, f5d04f59-1528-41b5-9775-3704c80d31e9, 55, Finished, Available, Finished)
# Help on function list_dataflows in module sempy_labs._dataflows:
#
# list_dataflows(workspace: Union[str, uuid.UUID, NoneType] = None)
#     Shows a list of all dataflows which exist within a workspace.
#
#     Parameters
#     ----------
#     workspace : str | uuid.UUID, default=None
#         The Fabric workspace name or ID.
#         Defaults to None which resolves to the workspace of the attached lakehouse
#         or if no lakehouse attached, resolves to the workspace of the notebook.
#
#     Returns
#     -------
#     pandas.DataFrame
#         A pandas dataframe showing the dataflows which exist within a workspace.

# %%
fabric.list_gateways()
# Out:
# StatementMeta(, f5d04f59-1528-41b5-9775-3704c80d31e9, 12, Finished, Available, Finished)
# Empty DataFrame
# Columns: [Gateway Id, Gateway Name, Gateway Type]
# Index: []

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, coalesce, current_date
from delta.tables import DeltaTable
import json
import pandas as pd
import requests
import concurrent.futures
import time
import msal
import datetime
# Out:
# StatementMeta(, 56c09688-a11b-4c7d-ae40-74848da01bb0, 11, Finished, Available, Finished)

# %%
import sempy_labs as labs
from sempy_labs import migration, directlake, admin, graph, vertipaq_analyzer
from sempy_labs import lakehouse as lake
from sempy_labs import report as rep
from sempy_labs.tom import connect_semantic_model
from sempy_labs.report import ReportWrapper
import sempy
sempy.fabric._client._utils._init_analysis_services()
import Microsoft.AnalysisServices.Tabular as TOM
# Out:
# StatementMeta(, 56c09688-a11b-4c7d-ae40-74848da01bb0, 12, Finished, Available, Finished)

# %%
import sempy.fabric as fabric
import pandas as pd
import datetime


from sempy_labs._helper_functions import (
    resolve_lakehouse_name,
    save_as_delta_table,
    resolve_workspace_capacity,
    retry,
    _get_column_aggregate,
    resolve_workspace_id,
    resolve_lakehouse_name_and_id,
)
from sempy_labs.lakehouse import (
    get_lakehouse_tables,
    lakehouse_attached,
)

from sempy_labs._model_bpa import run_model_bpa
from typing import Optional, List
from sempy._utils._log import log
import sempy_labs._icons as icons
from uuid import UUID
# Out:
# StatementMeta(, 56c09688-a11b-4c7d-ae40-74848da01bb0, 13, Finished, Available, Finished)

# %%
@log
def run_power_insighter(
    language: Optional[str] = None,
    workspace: Optional[str | UUID | List[str | UUID]] = None,
    skip_models: Optional[str | List[str]] = ["ModelBPA", "Fabric Capacity Metrics"],
    skip_models_in_workspace: Optional[dict] = None,
):
    """
    Runs all the sempy functions and then it will create a Semantic Model where you will get all the articats and directly you can do reporting

    Parameters
    ----------
    language : str, default=None
        The language (code) in which the rules will appear. For example, specifying 'it-IT' will show the Rule Name, Category and Description in Italian.
        Defaults to None which resolves to English.
    workspace : str | uuid.UUID | List[str | uuid.UUID], default=None
        The workspace or list of workspaces to scan. Supports both the workspace name and the workspace id.
        Defaults to None which scans all accessible workspaces.
    skip_models : str | List[str], default=['ModelBPA', 'Fabric Capacity Metrics']
        The semantic models to always skip when running this analysis.
    skip_models_in_workspace : dict, default=None
        A dictionary showing specific semantic models within specific workspaces to skip. See the example below:
        {
            "Workspace A": ["Dataset1", "Dataset2"],
            "Workspace B": ["Dataset5", "Dataset 8"],
        }
    """
    if not lakehouse_attached():
        raise ValueError(
            f"{icons.red_dot} No lakehouse is attached to this notebook. Must attach a lakehouse to the notebook."
        )

    if isinstance(skip_models, str):
        skip_models = [skip_models]

    skip_models.extend(["ModelBPA", "Fabric Capacity Metrics"])

    now = datetime.datetime.now()

    #Pulling all the workspaces details
    dfW = fabric.list_workspaces("type ne 'AdminInsights'")
    if workspace is None:
        dfW_filt = dfW.copy()
    else:
        dfW_filt = dfW[(dfW["Name"].isin(workspace)) | (dfW["Id"].isin(workspace))]

    if dfW_filt.empty:
        raise ValueError(
            f"{icons.red_dot} There are no valid workspaces to assess. This is likely due to not having proper permissions to the workspace(s) entered in the 'workspace' parameter."
        )

    # Convert 'Name' column to list
    workspaces_list = dfW_filt['Id'].tolist()



    all_dfD = pd.DataFrame()
    for _, r in dfW_filt.iterrows():
        wksp = r["Name"]
        wksp_id = r["Id"]
        # capacity_id, capacity_name = resolve_workspace_capacity(workspace=wksp)

        # df = pd.DataFrame(columns=list(icons.bpa_schema.keys()))

        # Get dataset details
        dfD = fabric.list_datasets(workspace=wksp, mode="rest")

        #Adding Workspace ID to the dataframe
        dfD["Workspace Id"] = wksp_id

        # Append to the master DataFrame
        all_dfD = pd.concat([all_dfD, dfD], ignore_index=True)

    #Pulling all apps 
    dfApps = fabric.list_apps()

    #Pulling all capacities
    dfCapacities = fabric.list_capacities()

    #List DataFlows
    dfDataFlows = fabric.list_dataflows()

    return dfW
# Out:
# StatementMeta(, 56c09688-a11b-4c7d-ae40-74848da01bb0, 14, Finished, Available, Finished)

# %%
@log
def run_power_insighter(
    language: Optional[str] = None,
    workspace: Optional[str | UUID | List[str | UUID]] = None,
    skip_models: Optional[str | List[str]] = ["ModelBPA", "Fabric Capacity Metrics"],
    skip_models_in_workspace: Optional[dict] = None,
):
    """
    Runs all the sempy functions and then it will create a Semantic Model where you will get all the articats and directly you can do reporting

    Parameters
    ----------
    language : str, default=None
        The language (code) in which the rules will appear. For example, specifying 'it-IT' will show the Rule Name, Category and Description in Italian.
        Defaults to None which resolves to English.
    workspace : str | uuid.UUID | List[str | uuid.UUID], default=None
        The workspace or list of workspaces to scan. Supports both the workspace name and the workspace id.
        Defaults to None which scans all accessible workspaces.
    skip_models : str | List[str], default=['ModelBPA', 'Fabric Capacity Metrics']
        The semantic models to always skip when running this analysis.
    skip_models_in_workspace : dict, default=None
        A dictionary showing specific semantic models within specific workspaces to skip. See the example below:
        {
            "Workspace A": ["Dataset1", "Dataset2"],
            "Workspace B": ["Dataset5", "Dataset 8"],
        }
    """
    if not lakehouse_attached():
        raise ValueError(
            f"{icons.red_dot} No lakehouse is attached to this notebook. Must attach a lakehouse to the notebook."
        )

    if isinstance(skip_models, str):
        skip_models = [skip_models]

    skip_models.extend(["ModelBPA", "Fabric Capacity Metrics"])

    now = datetime.datetime.now()

    #Pulling all the workspaces details
    dfW = fabric.list_workspaces("type ne 'AdminInsights'")
    if workspace is None:
        dfW_filt = dfW.copy()
    else:
        dfW_filt = dfW[(dfW["Name"].isin(workspace)) | (dfW["Id"].isin(workspace))]

    if dfW_filt.empty:
        raise ValueError(
            f"{icons.red_dot} There are no valid workspaces to assess. This is likely due to not having proper permissions to the workspace(s) entered in the 'workspace' parameter."
        )

    # Convert 'Name' column to list
    workspaces_list = dfW_filt['Id'].tolist()



    all_dfD = pd.DataFrame()
    all_DatasetSourceDetails = pd.DataFrame()
    all_dfApps = pd.DataFrame()
    all_dfDataFlows = pd.DataFrame()

    all_dfCapacities = fabric.list_capacities()
    for _, r in dfW_filt.iterrows():
        wksp = r["Name"]
        wksp_id = r["Id"]
        # capacity_id, capacity_name = resolve_workspace_capacity(workspace=wksp)

        # df = pd.DataFrame(columns=list(icons.bpa_schema.keys()))

        # Get dataset details
        dfD = fabric.list_datasets(workspace=wksp, mode="rest")

        #Adding Workspace ID to the dataframe
        dfD["Workspace Id"] = wksp_id
        print(type(dfD))

        # Append to the master DataFrame
        all_dfD = pd.concat([all_dfD, dfD], ignore_index=True)

        #Pulling all apps 
        all_dfApps = fabric.list_apps()

        #Pulling all capacities
        

        #List DataFlows
        # all_dfDataFlows = fabric.list_dataflows()

    return dfD
# Out:
# StatementMeta(, 56c09688-a11b-4c7d-ae40-74848da01bb0, 23, Finished, Available, Finished)

# %%
test = run_power_insighter()
# Out:
# StatementMeta(, 56c09688-a11b-4c7d-ae40-74848da01bb0, 24, Finished, Available, Finished)
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
test
# Out:
# StatementMeta(, 56c09688-a11b-4c7d-ae40-74848da01bb0, 16, Finished, Available, Finished)
#                                       Id  Is Read Only  \
# 0   35060111-ead1-48c7-90ad-6470f10fc59e         False
# 1   fd2fc524-9196-41e8-9ecb-2f4e8e8ded50         False
# 2   e86870f9-b5ef-4562-824c-4fb553d63e7b         False
# 3   83ec31a1-2ca3-46fe-a5f8-2bcc8e70f8cd         False
# 4   13a5a575-b5bb-4e9f-8e12-499d4af44889         False
# 5   7acb5d88-77de-4762-bb6d-57b1ce0afa46         False
# 6   228db8e8-6203-4ba8-b406-7b1da29c34c1         False
# 7   a912e8a5-7138-4452-88a1-5c7df2c99a5a         False
# 8   8b09a058-33d3-4ef3-a8dd-f4bc5e740652         False
# 9   8ba77fd7-a1ef-4837-8f15-915ba50d0f4a         False
# 10  343107fe-9342-43f7-bd04-d2f981e04b94         False
# 11  cdb45b81-d656-4b26-a53e-fb0f5fc8d6cb         False
# 12  b6d4552d-7596-496f-8618-88b4d1a2d66a         False
# 13  7de7a373-ed10-442d-9711-bfe74bf4bf2a         False
# 14  d3120490-76ae-4ef4-a440-2bd65732ccdc         False
# 15  4129f6ef-5746-4cc0-94f4-49dffdfd78d6         False
# 16  831affc2-2227-42e3-ac1d-a7a2dd1e9756         False
# 17  8a542b19-d8fd-44da-8738-9ac2262d6ee1         False
# 18  8d9ad378-56d4-4e6d-b038-43922061be87         False
# 19  a1612357-8714-46bf-8c10-dc5e6fd509ef         False
# 20  99454d31-f7ac-41b3-a128-a1a4ff89abf1         False
#
#     Is On Dedicated Capacity                           Capacity Id  \
# 0                       True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
# 1                       True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
# 2                       True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
# 3                       True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
# 4                      False                                   NaN
# 5                      False                                   NaN
# 6                       True  76f4499e-05ff-44a9-8c2f-323ee14ea1a7
# 7                      False                                   NaN
# 8                       True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
# 9                       True  517b62f7-2477-4809-a9d5-bfbec118442c
# 10                      True  69fed322-3e8e-48da-a633-1508dbf0a451
# 11                      True  69fed322-3e8e-48da-a633-1508dbf0a451
# 12                      True  517b62f7-2477-4809-a9d5-bfbec118442c
# 13                      True  517b62f7-2477-4809-a9d5-bfbec118442c
# 14                      True  bf38c7d0-e551-487d-a18e-3949eed35069
# 15                     False                                   NaN
# 16                      True  76f4499e-05ff-44a9-8c2f-323ee14ea1a7
# 17                      True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
# 18                      True  517b62f7-2477-4809-a9d5-bfbec118442c
# 19                      True  517b62f7-2477-4809-a9d5-bfbec118442c
# 20                      True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
#
#    Default Dataset Storage Format       Type  \
# 0                           Small  Workspace
# 1                           Small  Workspace
# 2                           Small  Workspace
# 3                           Small  Workspace
# 4                             NaN  Workspace
# 5                             NaN  Workspace
# 6                           Small  Workspace
# 7                             NaN  Workspace
# 8                           Small  Workspace
# 9                           Small  Workspace
# 10                          Small  Workspace
# 11                          Small  Workspace
# 12                          Small  Workspace
# 13                          Small  Workspace
# 14                          Large  Workspace
# 15                            NaN  Workspace
# 16                          Small  Workspace
# 17                          Small  Workspace
# 18                          Small  Workspace
# 19                          Small  Workspace
# 20                          Small  Workspace
#
#                                  Name
# 0            3. Domestic 2W Marketing
# 1                1. Domestic 2W Sales
# 2       5. Domestic 2W Digital Assets
# 3    2. Domestic 2W Dealer Management
# 4               Development_Workspace
# 5                               BI QC
# 6                P1 Priority Datasets
# 7              Beta Testing Workspace
# 8           7. International Business
# 9                       BI Governance
# 10            Paginated Reports - Dev
# 11           Paginated Reports - Prod
# 12      Domestic 3W Sales & Marketing
# 13                                OFG
# 14                Fabric Trial - Test
# 15  Microsoft Fabric Capacity Metrics
# 16        Domestic 2W Marketing - CXO
# 17    Domestic 2W Marketing - Non CXO
# 18                              SEMG
# 19                           SST D&AI
# 20                       Norton Group

# %%
fabric.list_datasources(workspace = "BI QC")
# Out:
# StatementMeta(, 366858a0-394d-4996-a191-60716f8dbf4c, 81, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[220], line 1
# ----> 1 fabric.list_datasources(workspace = "BI QC")
#
# File /nfs4/pyenv-a544998e-0f2c-4ad5-b781-681eff2de360/lib/python3.10/site-packages/sempy/_utils/_log.py:361, in mds_log.<locals>.get_wrapper.<locals>.log_decorator_wrapper(*args, **kwargs)
#     358     extra.update(extractor.get_initialization_mds_fields())
#     360     s = inspect.signature(func)
# --> 361     arg_dict = s.bind(*args, **kwargs).arguments
#     363 except Exception:
#     364     extractor.logger.error(message, extra, exc_info=True)
#
# File ~/cluster-env/trident_env/lib/python3.10/inspect.py:3186, in Signature.bind(self, *args, **kwargs)
#    3181 def bind(self, /, *args, **kwargs):
#    3182     """Get a BoundArguments object, that maps the passed `args`
#    3183     and `kwargs` to the function's signature.  Raises `TypeError`
#    3184     if the passed arguments can not be bound.
#    3185     """
# -> 3186     return self._bind(args, kwargs)
#
# File ~/cluster-env/trident_env/lib/python3.10/inspect.py:3101, in Signature._bind(self, args, kwargs, partial)
#    3099                 msg = 'missing a required argument: {arg!r}'
#    3100                 msg = msg.format(arg=param.name)
# -> 3101                 raise TypeError(msg) from None
#    3102 else:
#    3103     # We have a positional argument to process
#    3104     try:
#
# TypeError: missing a required argument: 'dataset'

# %%
help(fabric.list_datasources)
# Out:
# StatementMeta(, 366858a0-394d-4996-a191-60716f8dbf4c, 80, Finished, Available, Finished)
# Help on function list_datasources in module sempy.fabric._flat_list_datasources:
#
# list_datasources(dataset: Union[str, uuid.UUID], additional_xmla_properties: Union[str, List[str], NoneType] = None, workspace: Union[str, uuid.UUID, NoneType] = None) -> pandas.core.frame.DataFrame
#     List all datasources in a dataset.
#
#     Parameters
#     ----------
#     dataset : str or uuid.UUID
#         Name or UUID of the dataset.
#     additional_xmla_properties : str or List[str], default=None
#         Additional XMLA `datasource <https://learn.microsoft.com/en-us/dotnet/api/microsoft.analysisservices.tabular.datasource?view=analysisservices-dotnet>`_
#         properties to include in the returned dataframe.
#     workspace : str or uuid.UUID, default=None
#         The Fabric workspace name or UUID object containing the workspace ID.
#         Defaults to None which resolves to the workspace of the attached lakehouse
#         or if no lakehouse attached, resolves to the workspace of the notebook.
#
#     Returns
#     -------
#     pandas.DataFrame
#         Dataframe listing all datasources.

# %%
display(test)
# Out:
# StatementMeta(, 366858a0-394d-4996-a191-60716f8dbf4c, 74, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 90c69a54-aa3c-47f7-aa17-5f4d3f7f817c)

# %%
help(fabric.list_datasets)
# Out:
# StatementMeta(, 366858a0-394d-4996-a191-60716f8dbf4c, 68, Finished, Available, Finished)
# Help on function list_datasets in module sempy.fabric._flat:
#
# list_datasets(workspace: Union[str, uuid.UUID, NoneType] = None, mode: str = 'xmla', additional_xmla_properties: Union[str, List[str], NoneType] = None) -> pandas.core.frame.DataFrame
#     List datasets in a `Fabric workspace <https://learn.microsoft.com/en-us/fabric/get-started/workspaces>`_.
#
#     Parameters
#     ----------
#     workspace : str or uuid.UUID, default=None
#         The Fabric workspace name or UUID object containing the workspace ID.
#         Defaults to None which resolves to the workspace of the attached lakehouse
#         or if no lakehouse attached, resolves to the workspace of the notebook.
#     mode : str, default="xmla"
#         Whether to use the XMLA "xmla" or REST API "rest".
#         See `REST docs <https://learn.microsoft.com/en-us/rest/api/power-bi/datasets/get-datasets>`_ for returned fields.
#     additional_xmla_properties : str or List[str], default=None
#         Additional XMLA `model <https://learn.microsoft.com/en-us/dotnet/api/microsoft.analysisservices.tabular.model?view=analysisservices-dotnet>`_
#         properties to include in the returned dataframe.
#
#     Returns
#     -------
#     pandas.DataFrame
#         Dataframe listing databases and their attributes.

# %%
print(test)
# Out:
# StatementMeta(, 366858a0-394d-4996-a191-60716f8dbf4c, 65, Finished, Available, Finished)
# ['7acb5d88-77de-4762-bb6d-57b1ce0afa46', '8ba77fd7-a1ef-4837-8f15-915ba50d0f4a']

# %%
dfW = fabric.list_workspaces("type ne 'AdminInsights'")
# Out:
# StatementMeta(, 366858a0-394d-4996-a191-60716f8dbf4c, 32, Finished, Available, Finished)

# %%
dfW
# Out:
# StatementMeta(, 366858a0-394d-4996-a191-60716f8dbf4c, 33, Finished, Available, Finished)
#                                       Id  Is Read Only  \
# 0   35060111-ead1-48c7-90ad-6470f10fc59e         False
# 1   fd2fc524-9196-41e8-9ecb-2f4e8e8ded50         False
# 2   e86870f9-b5ef-4562-824c-4fb553d63e7b         False
# 3   83ec31a1-2ca3-46fe-a5f8-2bcc8e70f8cd         False
# 4   13a5a575-b5bb-4e9f-8e12-499d4af44889         False
# 5   7acb5d88-77de-4762-bb6d-57b1ce0afa46         False
# 6   228db8e8-6203-4ba8-b406-7b1da29c34c1         False
# 7   a912e8a5-7138-4452-88a1-5c7df2c99a5a         False
# 8   8b09a058-33d3-4ef3-a8dd-f4bc5e740652         False
# 9   8ba77fd7-a1ef-4837-8f15-915ba50d0f4a         False
# 10  343107fe-9342-43f7-bd04-d2f981e04b94         False
# 11  cdb45b81-d656-4b26-a53e-fb0f5fc8d6cb         False
# 12  b6d4552d-7596-496f-8618-88b4d1a2d66a         False
# 13  7de7a373-ed10-442d-9711-bfe74bf4bf2a         False
# 14  d3120490-76ae-4ef4-a440-2bd65732ccdc         False
# 15  4129f6ef-5746-4cc0-94f4-49dffdfd78d6         False
# 16  831affc2-2227-42e3-ac1d-a7a2dd1e9756         False
# 17  8a542b19-d8fd-44da-8738-9ac2262d6ee1         False
# 18  8d9ad378-56d4-4e6d-b038-43922061be87         False
# 19  a1612357-8714-46bf-8c10-dc5e6fd509ef         False
# 20  99454d31-f7ac-41b3-a128-a1a4ff89abf1         False
#
#     Is On Dedicated Capacity                           Capacity Id  \
# 0                       True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
# 1                       True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
# 2                       True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
# 3                       True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
# 4                      False                                   NaN
# 5                      False                                   NaN
# 6                       True  76f4499e-05ff-44a9-8c2f-323ee14ea1a7
# 7                      False                                   NaN
# 8                       True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
# 9                       True  517b62f7-2477-4809-a9d5-bfbec118442c
# 10                      True  69fed322-3e8e-48da-a633-1508dbf0a451
# 11                      True  69fed322-3e8e-48da-a633-1508dbf0a451
# 12                      True  517b62f7-2477-4809-a9d5-bfbec118442c
# 13                      True  517b62f7-2477-4809-a9d5-bfbec118442c
# 14                      True  bf38c7d0-e551-487d-a18e-3949eed35069
# 15                     False                                   NaN
# 16                      True  76f4499e-05ff-44a9-8c2f-323ee14ea1a7
# 17                      True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
# 18                      True  517b62f7-2477-4809-a9d5-bfbec118442c
# 19                      True  517b62f7-2477-4809-a9d5-bfbec118442c
# 20                      True  22b9217a-6e1d-4f0d-ac84-cd31903c88a2
#
#    Default Dataset Storage Format       Type  \
# 0                           Small  Workspace
# 1                           Small  Workspace
# 2                           Small  Workspace
# 3                           Small  Workspace
# 4                             NaN  Workspace
# 5                             NaN  Workspace
# 6                           Small  Workspace
# 7                             NaN  Workspace
# 8                           Small  Workspace
# 9                           Small  Workspace
# 10                          Small  Workspace
# 11                          Small  Workspace
# 12                          Small  Workspace
# 13                          Small  Workspace
# 14                          Large  Workspace
# 15                            NaN  Workspace
# 16                          Small  Workspace
# 17                          Small  Workspace
# 18                          Small  Workspace
# 19                          Small  Workspace
# 20                          Small  Workspace
#
#                                  Name
# 0            3. Domestic 2W Marketing
# 1                1. Domestic 2W Sales
# 2       5. Domestic 2W Digital Assets
# 3    2. Domestic 2W Dealer Management
# 4               Development_Workspace
# 5                               BI QC
# 6                P1 Priority Datasets
# 7              Beta Testing Workspace
# 8           7. International Business
# 9                       BI Governance
# 10            Paginated Reports - Dev
# 11           Paginated Reports - Prod
# 12      Domestic 3W Sales & Marketing
# 13                                OFG
# 14                Fabric Trial - Test
# 15  Microsoft Fabric Capacity Metrics
# 16        Domestic 2W Marketing - CXO
# 17    Domestic 2W Marketing - Non CXO
# 18                              SEMG
# 19                           SST D&AI
# 20                       Norton Group

# %%
dir(fabric)
# Out:
# StatementMeta(, 366858a0-394d-4996-a191-60716f8dbf4c, 28, Finished, Available, Finished)
# ['CognitiveServiceRestClient',
#  'DataCategory',
#  'FabricDataFrame',
#  'FabricRestClient',
#  'FabricSeries',
#  'MetadataKeys',
#  'ModelCalcDependencies',
#  'PowerBIRestClient',
#  'RefreshExecutionDetails',
#  'TOMWrapper',
#  'Trace',
#  'TraceConnection',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '_bpa',
#  '_cache',
#  '_client',
#  '_datacategory',
#  '_dataframe',
#  '_environment',
#  '_flat',
#  '_flat_list_annotations',
#  '_flat_list_apps',
#  '_flat_list_calculation_items',
#  '_flat_list_columns',
#  '_flat_list_dataflows',
#  '_flat_list_datasources',
#  '_flat_list_gateways',
#  '_flat_list_hierarchies',
#  '_flat_list_partitions',
#  '_flat_list_perspectives',
#  '_flat_list_relationships',
#  '_metadatakeys',
#  '_token_provider',
#  '_trace',
#  '_trace_evaluate_dax',
#  '_utils',
#  '_vertipaq',
#  'connect_semantic_model',
#  'create_lakehouse',
#  'create_notebook',
#  'create_tom_server',
#  'create_trace_connection',
#  'create_workspace',
#  'delete_item',
#  'evaluate_dax',
#  'evaluate_measure',
#  'exceptions',
#  'execute_tmsl',
#  'execute_xmla',
#  'get_artifact_id',
#  'get_lakehouse_id',
#  'get_model_calc_dependencies',
#  'get_notebook_workspace_id',
#  'get_refresh_execution_details',
#  'get_roles',
#  'get_row_level_security_permissions',
#  'get_tmsl',
#  'get_workspace_id',
#  'list_annotations',
#  'list_apps',
#  'list_calculation_items',
#  'list_capacities',
#  'list_columns',
#  'list_dataflow_storage_accounts',
#  'list_dataflows',
#  'list_datasets',
#  'list_datasources',
#  'list_expressions',
#  'list_gateways',
#  'list_hierarchies',
#  'list_items',
#  'list_measures',
#  'list_partitions',
#  'list_perspectives',
#  'list_refresh_requests',
#  'list_relationship_violations',
#  'list_relationships',
#  'list_reports',
#  'list_tables',
#  'list_translations',
#  'list_workspaces',
#  'log_telemetry',
#  'model_memory_analyzer',
#  'plot_relationships',
#  'read_parquet',
#  'read_table',
#  'refresh_dataset',
#  'refresh_tom_cache',
#  'resolve_dataset_id',
#  'resolve_dataset_name',
#  'resolve_dataset_name_and_id',
#  'resolve_item_id',
#  'resolve_item_name',
#  'resolve_workspace_id',
#  'resolve_workspace_name',
#  'resolve_workspace_name_and_id',
#  'run_model_bpa',
#  'run_notebook_job',
#  'translate_semantic_model']

# %%
display(test)
# Out:
# StatementMeta(, 366858a0-394d-4996-a191-60716f8dbf4c, 27, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 429c2d38-c019-4c25-8d97-5b13799106d7)

# %%
import pandas as pd
from sempy_labs._helper_functions import (
    resolve_workspace_name_and_id,
    _is_valid_uuid,
    _update_dataframe_datatypes,
    _base_api,
    _create_dataframe,
    resolve_workspace_name,
)
from typing import Optional, Tuple, List
import sempy_labs._icons as icons
from uuid import UUID
import sempy.fabric as fabric


def list_dataflows(workspace: Optional[str | UUID | List[str | UUID]] = None):
    """
    Shows a list of all dataflows which exist within specified or all workspaces .

    Parameters
    ----------
    workspace : str | uuid.UUID | List[str | uuid.UUID], default=None
        The workspace or list of workspaces to scan. Supports both the workspace name and the workspace id.
        Defaults to None which scans all accessible workspaces.

    Returns
    -------
    pandas.DataFrame
        A pandas dataframe showing the dataflows which exist within a workspace.
    """

    #Pulling all the workspaces details
    dfW = fabric.list_workspaces("type ne 'AdminInsights'")
    if workspace is None:
        dfW_filt = dfW.copy()
    else:
        if isinstance(workspace, str):
            workspace = [workspace]
        dfW_filt = dfW[(dfW["Name"].isin(workspace)) | (dfW["Id"].isin(workspace))]

    if dfW_filt.empty:
        raise ValueError(
            f"{icons.red_dot} There are no valid workspaces to assess. This is likely due to not having proper permissions to the workspace(s) entered in the 'workspace' parameter."
        )

    # Convert 'Name' column to list
    workspaces_list = dfW_filt['Id'].tolist()


    columns = {
        "Workspace Id": "string",
        "Workspace Name": "string",
        "Dataflow Id": "string",
        "Dataflow Name": "string",
        "Configured By": "string",
        "Users": "string",
        "Generation": "int",
    }
    df = _create_dataframe(columns=columns)

    
    for workspace_id in workspaces_list:
        (workspace_name, workspace_id) = resolve_workspace_name_and_id(workspace_id)
        response = _base_api(request=f"/v1.0/myorg/groups/{workspace_id}/dataflows")

        data = []  # Collect rows here

        for v in response.json().get("value", []):
            new_data = {
                "Workspace Id": workspace_id,
                "Workspace Name": workspace_name,
                "Dataflow Id": v.get("objectId"),
                "Dataflow Name": v.get("name"),
                "Configured By": v.get("configuredBy"),
                "Users": v.get("users", []),
                "Generation": v.get("generation"),
            }
            data.append(new_data)

        if data:
            df_temp = pd.DataFrame(data)
            _update_dataframe_datatypes(dataframe=df_temp, column_map=columns)
            df = pd.concat([df, df_temp], ignore_index=True)

    return df
# Out:
# StatementMeta(, 5b0f876c-3857-479a-9aef-b2194ad3d831, 59, Finished, Available, Finished)

# %%
workspace = ["SST D&AI","8b09a058-33d3-4ef3-a8dd-f4bc5e740652"]
# Out:
# StatementMeta(, 5b0f876c-3857-479a-9aef-b2194ad3d831, 56, Finished, Available, Finished)

# %%
test = list_dataflows(workspace = "SST D&AI")
# Out:
# StatementMeta(, 5b0f876c-3857-479a-9aef-b2194ad3d831, 62, Finished, Available, Finished)

# %%
display(test)
# Out:
# StatementMeta(, 5b0f876c-3857-479a-9aef-b2194ad3d831, 63, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ba4d1944-4136-4157-8a51-0c7385fc5815)

# %%
test = list_dataflows(workspace = ["SST D&AI","8b09a058-33d3-4ef3-a8dd-f4bc5e740652"])
# Out:
# StatementMeta(, f5d04f59-1528-41b5-9775-3704c80d31e9, 83, Finished, Available, Finished)

# %%
import sempy.fabric as fabric
import pandas as pd
import datetime
from sempy_labs._helper_functions import (
    save_as_delta_table,
    resolve_workspace_capacity,
    retry,
    _get_column_aggregate,
    resolve_workspace_id,
    resolve_lakehouse_name_and_id,
)
from sempy_labs.lakehouse import (
    get_lakehouse_tables,
    lakehouse_attached,
)
from sempy_labs._model_bpa import run_model_bpa
from typing import Optional, List
from sempy._utils._log import log
import sempy_labs._icons as icons
from uuid import UUID
# Out:
# StatementMeta(, 30d88d90-4800-4e92-92f1-49c9ba35c7de, 12, Finished, Available, Finished)

# %%
@log
def create_model_bpa_semantic_model(
    dataset: Optional[str] = icons.model_bpa_name,
    lakehouse: Optional[str | UUID] = None,
    lakehouse_workspace: Optional[str | UUID] = None,
):
    """
    Dynamically generates a Direct Lake semantic model based on the 'modelbparesults' delta table which contains the Best Practice Analyzer results.
    This semantic model used in combination with the corresponding Best Practice Analyzer report can be used to analyze multiple semantic models
    on multiple workspaces at once (and over time).

    The semantic model is always created within the same workspace as the lakehouse.

    Parameters
    ----------
    dataset : str, default='ModelBPA'
        Name of the semantic model to be created.
    lakehouse : str | uuid.UUID, default=None
        Name of the Fabric lakehouse which contains the 'modelbparesults' delta table.
        Defaults to None which resolves to the default lakehouse attached to the notebook.
    lakehouse_workspace : str | uuid.UUID, default=None
        The workspace in which the lakehouse resides.
        Defaults to None which resolves to the workspace of the attached lakehouse
        or if no lakehouse attached, resolves to the workspace of the notebook.
    """

    from sempy_labs.directlake import (
        generate_shared_expression,
        add_table_to_direct_lake_semantic_model,
    )
    from sempy_labs import create_blank_semantic_model, refresh_semantic_model
    from sempy_labs.tom import connect_semantic_model

    lakehouse_workspace_id = resolve_workspace_id(workspace=lakehouse_workspace)
    (lakehouse_id, lakehouse_name) = resolve_lakehouse_name_and_id(
        lakehouse=lakehouse, workspace=lakehouse_workspace_id
    )

    # Generate the shared expression based on the lakehouse and lakehouse workspace
    expr = generate_shared_expression(
        item_name=lakehouse_name,
        item_type="Lakehouse",
        workspace=lakehouse_workspace_id,
    )

    # Create blank model
    create_blank_semantic_model(
        dataset=dataset, workspace=lakehouse_workspace_id, overwrite=True
    )

    @retry(
        sleep_time=1,
        timeout_error_message=f"{icons.red_dot} Function timed out after 1 minute",
    )
    def dyn_connect():
        with connect_semantic_model(
            dataset=dataset, readonly=True, workspace=lakehouse_workspace_id
        ) as tom:

            tom.model

    dyn_connect()
    icons.sll_tags.append("ModelBPABulk")
    table_exists = False
    with connect_semantic_model(
        dataset=dataset, readonly=False, workspace=lakehouse_workspace_id
    ) as tom:
        t_name = "BPAResults"
        t_name_full = f"'{t_name}'"
        # Create the shared expression
        if not any(e.Name == "DatabaseQuery" for e in tom.model.Expressions):
            tom.add_expression(name="DatabaseQuery", expression=expr)
        # Add the table to the model
        if any(t.Name == t_name for t in tom.model.Tables):
            table_exists = True
    if not table_exists:
        add_table_to_direct_lake_semantic_model(
            dataset=dataset,
            table_name=t_name,
            lakehouse_table_name="modelbparesults",
            workspace=lakehouse_workspace_id,
            refresh=False,
        )
    with connect_semantic_model(
        dataset=dataset, readonly=False, workspace=lakehouse_workspace_id
    ) as tom:
        # Fix column names
        for c in tom.all_columns():
            if c.Name == "Dataset_Name":
                c.Name = "Model"
            elif c.Name == "Dataset_Id":
                c.Name = "Model Id"
            elif c.Name == "Workspace_Name":
                c.Name = "Workspace"
            elif c.Name == "Capacity_Name":
                c.Name = "Capacity"
            elif c.Name == "Configured_By":
                c.Name = "Model Owner"
            elif c.Name == "URL":
                c.DataCategory = "WebURL"
            elif c.Name == "RunId":
                tom.set_summarize_by(
                    table_name=c.Parent.Name, column_name=c.Name, value="None"
                )
            c.Name = c.Name.replace("_", " ")

        # Implement pattern for base measures
        def get_expr(table_name, calculation):
            return f"IF(HASONEFILTER({table_name}[RunId]),{calculation},CALCULATE({calculation},FILTER(VALUES({table_name}[RunId]),{table_name}[RunId] = [Max Run Id])))"

        # Add measures
        int_format = "#,0"
        m_name = "Max Run Id"
        if not any(m.Name == m_name for m in tom.all_measures()):
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=f"CALCULATE(MAX({t_name_full}[RunId]),{t_name_full}[RunId])",
                format_string=int_format,
            )
        m_name = "Capacities"
        if not any(m.Name == m_name for m in tom.all_measures()):
            calc = f"COUNTROWS(DISTINCT({t_name_full}[Capacity]))"
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=get_expr(t_name_full, calc),
                format_string=int_format,
            )
        m_name = "Models"
        if not any(m.Name == m_name for m in tom.all_measures()):
            calc = f"COUNTROWS(DISTINCT({t_name_full}[Model]))"
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=get_expr(t_name_full, calc),
                format_string=int_format,
            )
        m_name = "Workspaces"
        if not any(m.Name == m_name for m in tom.all_measures()):
            calc = f"COUNTROWS(DISTINCT({t_name_full}[Workspace]))"
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=get_expr(t_name_full, calc),
                format_string=int_format,
            )
        m_name = "Violations"
        if not any(m.Name == m_name for m in tom.all_measures()):
            calc = f"COUNTROWS({t_name_full})"
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=get_expr(t_name_full, calc),
                format_string=int_format,
            )
        m_name = "Error Violations"
        if not any(m.Name == m_name for m in tom.all_measures()):
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=f'CALCULATE([Violations],{t_name_full}[Severity]="Error")',
                format_string=int_format,
            )
        m_name = "Rules Violated"
        if not any(m.Name == m_name for m in tom.all_measures()):
            calc = f"COUNTROWS(DISTINCT({t_name_full}[Rule Name]))"
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=get_expr(t_name_full, calc),
                format_string=int_format,
            )
        m_name = "Rule Severity"
        if not any(m.Name == m_name for m in tom.all_measures()):
            tom.add_measure(
                table_name=t_name,
                measure_name=m_name,
                expression=f"IF(ISFILTERED({t_name_full}[Rule Name]),IF( HASONEVALUE({t_name_full}[Rule Name]),MIN({t_name_full}[Severity])))",
            )
        # tom.add_measure(table_name=t_name, measure_name='Rules Followed', expression="[Rules] - [Rules Violated]")

    # Refresh the model
    refresh_semantic_model(dataset=dataset, workspace=lakehouse_workspace_id)
# Out:
# StatementMeta(, 30d88d90-4800-4e92-92f1-49c9ba35c7de, 13, Finished, Available, Finished)
